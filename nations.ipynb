# %% [markdown]
# # Nations dataset
#
# > Ejercicio practico para la carga de datos

# %%
# Importaresmo algunasd de las librerias mas clasicas para el manejod e datos en python
# Pandas es la librerioa basica para la manipuilacion y analicis de datos
import pandas as pd

# Numpy es la libreria para la manipulacion y creacion de vectores y matrices, ademas de algunas funciones matematicas
import numpy as np

# Matplotlib es la libreria para la creacion de graficos
import matplotlib.pyplot as plt

# Seaborn es una libreria para la creacion de graficos estadisticos
import seaborn as sns

# Statsmodels es una libreria para la creacion de modelos estadisticos
import statsmodels.formula.api as smf

# Libreria para el tratamiento de variables categoricas
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
# Carga de datos
df_nations = pd.read_csv('dataset/nations.csv', encoding='latin-1')
df_nations
# Out:
#      Unnamed: 0          country   region           gdp     school  \
# 0             1          Algeria   Africa   7300.399902   6.716667
# 1             2            Benin   Africa   1338.800049   3.100000
# 2             3         Botswana   Africa  12307.400391   8.600000
# 3             4     Burkina Faso   Africa   1063.400024   1.300000
# 4             5          Burundi   Africa    349.200012   2.483333
# ..          ...              ...      ...           ...        ...
# 189         190            Samoa  Oceania   4012.600098  10.300000
# 190         191  Solomon Islands  Oceania   2249.199951   4.500000
# 191         192            Tonga  Oceania   4072.199951  10.133333
# 192         193           Tuvalu  Oceania           NaN        NaN
# 193         194          Vanuatu  Oceania   3809.800049   6.700000
#
#          adfert  chldmort       life       pop      urban  femlab   literacy  \
# 0      7.300000     34.75  72.316666  34172236  64.933334  0.4522  72.599998
# ...

# %%
# Metodo head() nos muetsra las primeras 5 observaciones
df_nations.head()
# Out:
#    Unnamed: 0       country  region           gdp    school      adfert  \
# 0           1       Algeria  Africa   7300.399902  6.716667    7.300000
# 1           2         Benin  Africa   1338.800049  3.100000  111.699997
# 2           3      Botswana  Africa  12307.400391  8.600000   52.099998
# 3           4  Burkina Faso  Africa   1063.400024  1.300000  124.800003
# 4           5       Burundi  Africa    349.200012  2.483333   18.600000
#
#    chldmort       life       pop      urban  femlab   literacy   co2  \
# 0     34.75  72.316666  34172236  64.933334  0.4522  72.599998  15.0
# 1    122.75  54.733334   8237634  41.000000  0.8482  41.700001   1.2
# 2     60.25  52.250000   1941233  59.250000  0.8870  84.099998   9.2
# 3    170.50  53.783333  15308383  23.583334  0.8584  23.600000   0.2
# 4    168.50  48.866665   7821783  10.250000  1.0344  66.599998   0.1
#
#         gini
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  33.299999

# %%
# Metodo tail muetra las ultimas 5 observaciones
df_nations.tail()
# Out:
#      Unnamed: 0          country   region          gdp     school     adfert  \
# 189         190            Samoa  Oceania  4012.600098  10.300000  28.299999
# 190         191  Solomon Islands  Oceania  2249.199951   4.500000  70.300003
# 191         192            Tonga  Oceania  4072.199951  10.133333  22.299999
# 192         193           Tuvalu  Oceania          NaN        NaN  23.299999
# 193         194          Vanuatu  Oceania  3809.800049   6.700000  54.000000
#
#      chldmort       life     pop      urban  femlab   literacy   co2  gini
# 189     26.75  71.533333  181600  20.666668  0.5010  98.800003  3.10   NaN
# 190     36.00  66.500000  503617  17.766666  0.4858        NaN  1.40   NaN
# 191     19.25  71.833336  102550  23.266666  0.7150  99.000000  4.85   NaN
# 192     36.50  66.033333    9767  49.233334     NaN        NaN   NaN   NaN
# 193     17.75  69.966667  225317  24.500000  0.8988  82.000000  1.50   NaN

# %%
# Metodo sample() podemos escojer la cantidad de observaciones ademas de agregar un random_state para mostrar observaci0ones aleatorias
df_nations.sample(5, random_state=1582)
# Out:
#      Unnamed: 0            country  region           gdp     school  \
# 8             9               Chad  Africa   1266.199951   1.500000
# 125         126          Sri Lanka    Asia   3975.600098   8.066667
# 15           16  Equatorial Guinea  Africa  27645.800781   5.400000
# 97           98            Georgia    Asia   4157.200195  12.100000
# 109         110                Lao    Asia   1856.199951   4.400000
#
#          adfert  chldmort       life       pop      urban  femlab   literacy  \
# 8    164.500000    209.00  48.566666  10509983  26.400000  0.8006  33.599998
# 125   23.600000     15.75  74.400002  20363284  14.466667  0.4644  90.699997
# 15   122.900002    149.50  50.066666    653533  39.266666  0.4140  93.300003
# 97    44.700001     30.25  73.133331   4409267  52.599998  0.7528  99.699997
# 109   39.000000     63.50  65.883331   5976884  30.283333  0.9862  72.699997
#
#            co2       gini
# 8     0.100000        NaN
# 125   2.250000  40.299999
# ...

# %%
# La columna Unnamed: 0 no presenta importancia para algun analisis por loq ue la borraremos con el metodo drop()
df_nations.drop(columns = ['Unnamed: 0'], inplace = True)
df_nations.sample(7)
# Out:
#          country    region           gdp  school      adfert  chldmort  \
# 179       Angola   Oceania   4662.000000    4.40  171.100006    170.00
# 142     Bulgaria    Europe  10998.200195   10.30   42.799999     11.50
# 63          Cuba  Americas           NaN    9.65   45.200001      6.25
# 133   Uzbekistan      Asia   2295.600098   10.00   13.800000     40.25
# 183  Marshall Is   Oceania           NaN    9.80   53.500000     36.00
# 64      Dominica  Americas   7800.399902    7.70   20.000000     10.75
# 100    Indonesia      Asia   3518.399902    5.55   45.099998     42.00
#
#           life        pop      urban  femlab   literacy        co2       gini
# 179  49.666668   17783300  56.250000  0.8380  70.000000   2.250000        NaN
# 142  72.783333    7616200  70.816666  0.7984  98.300003  22.599998  45.299999
# 63   78.400002   11262583  75.400002  0.6018  99.800003   8.850000        NaN
# 133  67.550003   26674950  36.400002  0.8224  99.300003  15.600000        NaN
# ...

# %%
# El metodo colums nos permite obtener una lista con las variabels del dataset
df_nations.columns
# Out:
# Index(['country', 'region', 'gdp', 'school', 'adfert', 'chldmort', 'life',
#        'pop', 'urban', 'femlab', 'literacy', 'co2', 'gini'],
#       dtype='object')

# %%
# Si deseamos obserbar una columna en espesifico del dataset 
df_nations['region']
# Out:
# 0       Africa
# 1       Africa
# 2       Africa
# 3       Africa
# 4       Africa
#         ...
# 189    Oceania
# 190    Oceania
# 191    Oceania
# 192    Oceania
# 193    Oceania
# Name: region, Length: 194, dtype: object

# %%
df_nations['country']
# Out:
# 0              Algeria
# 1                Benin
# 2             Botswana
# 3         Burkina Faso
# 4              Burundi
#             ...
# 189              Samoa
# 190    Solomon Islands
# 191              Tonga
# 192             Tuvalu
# 193            Vanuatu
# Name: country, Length: 194, dtype: object

# %%
df_nations['gini']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4      33.299999
#          ...
# 189          NaN
# 190          NaN
# 191          NaN
# 192          NaN
# 193          NaN
# Name: gini, Length: 194, dtype: float64

# %%
df_nations['gdp_peso2024'] = df_nations['gdp'] * 969
df_nations.sample(7)
# Out:
#          country    region           gdp     school      adfert  chldmort  \
# 28        Malawi    Africa    660.400024   3.816667  119.199997    120.25
# 54       Bahamas  Americas           NaN   8.500000   31.799999     13.75
# 37        Rwanda    Africa    954.000000   3.050000   38.700001    122.50
# 150       Greece    Europe  26118.000000   9.950000   11.600000      4.00
# 97       Georgia      Asia   4157.200195  12.100000   44.700001     30.25
# 166       Poland    Europe  15446.400391   9.816667   14.800000      7.25
# 80   Saint Lucia  Americas   8970.000000   8.300000   61.700001     19.00
#
#           life       pop      urban  femlab   literacy        co2       gini  \
# 28   51.316666  13825916  18.549999  0.9520  73.699997   0.300000        NaN
# 54   74.599998    331233  83.599998  0.8656        NaN  23.950001        NaN
# 37   53.849998   9882167  18.183332  1.0156  70.699997   0.300000  53.099998
# ...

# %% [markdown]
# ### Para continuar el taller responderemos la siguiente serie de interrogantes:
#
# * ¿Que tipo de atributos encontramos en el dataset?
# * ¿Cuantos datos tenemos en cada region?
# * ¿Cuantos paises tienen indices de CO2 mas altos que el promedio?
# * ¿que se puede decir del alfavetismo en africa o europa?

# %%
# Repuesta pregunta 1, ¿Que tipo de atributos encontramos en el dataset?
df_nations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       194 non-null    object
#  1   region        194 non-null    object
#  2   gdp           179 non-null    float64
#  3   school        188 non-null    float64
#  4   adfert        194 non-null    float64
#  5   chldmort      193 non-null    float64
#  6   life          194 non-null    float64
#  7   pop           194 non-null    int64
#  8   urban         194 non-null    float64
#  9   femlab        177 non-null    float64
#  10  literacy      135 non-null    float64
#  11  co2           185 non-null    float64
#  12  gini          81 non-null     float64
#  13  gdp_peso2024  179 non-null    float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 21.3+ KB

# %%
# El metodo describe() nos da unr esumen con la estadistica basica
df_nations.describe()
# Out:
#                 gdp      school      adfert    chldmort        life  \
# count    179.000000  188.000000  194.000000  193.000000  194.000000
# mean   12118.739193    7.459220   51.814433   47.650259   68.729295
# std    13942.341217    2.959589   44.066120   52.809400   10.055404
# min      279.799988    1.150000    1.000000    2.250000   45.849998
# 25%     2100.300049    5.225000   16.500000   10.250000   63.745833
# 50%     6932.799805    7.950000   39.350000   24.000000   72.183331
# 75%    17576.299805    9.850000   74.375002   69.750000   75.545835
# max    74906.000000   12.700000  207.100006  209.000000   82.766663
#
#                 pop       urban      femlab    literacy         co2  \
# count  1.940000e+02  194.000000  177.000000  135.000000  185.000000
# mean   3.437752e+07   55.434880    0.691606   81.533148   17.885946
# std    1.314004e+08   23.439101    0.182871   19.466359   25.670704
# min    9.767000e+03   10.250000    0.194200   23.600000    0.100000
# ...

# %%
# podemos hacer una estadistica descriptiva de una variable en particular del dataset
df_nations['gini'].describe()
# Out:
# count    81.000000
# mean     40.477778
# std       8.487874
# min      19.000000
# 25%      34.000000
# 50%      39.700001
# 75%      46.200001
# max      58.500000
# Name: gini, dtype: float64

# %%
# con el metodo mean podemos observar el valor promedio de una variable
df_nations['gini'].mean()
# Out:
# 40.4777778107443

# %%
# con count podemos validar la cantidad de datos de una columna
df_nations['gini'].count()
# Out:
# 81

# %%
# valor promedio de gdp
df_nations['gdp'].mean()
# Out:
# 12118.739193367559

# %%
# valor minimo de alfabetismo
df_nations['literacy'].min()
# Out:
# 23.6000003814697

# %%
# Respuesta pregunta 2, ¿Cuantos datos tenemos en cada region?
# Para saber cuantos datos tenemos en cada region, vamos a usar la funcion .value_counts()
# value_counts() ordena los datos de mayor a menor y los imprime en forma de tabla.
df_nations.value_counts('region')
# Out:
# region
# Africa      52
# Asia        49
# Europe      43
# Americas    35
# Oceania     15
# Name: count, dtype: int64

# %%
# otra forma de hacer conteo es con el metodo de agrupacion groupby
df_nations.groupby(['region'])[['country']].count()
# Out:
#           country
# region
# Africa         52
# Americas       35
# Asia           49
# Europe         43
# Oceania        15

# %%
# Respuesta pregunta 3, ¿Cuantos paises tienen indices de CO2 mas altos que el promedio?
# Con el metodo where se filtran los paises que tienen indices de CO2 mas altos que el promedio y mas bajos tambien
df_nations['co2_record'] = np.where(df_nations['co2'] > df_nations['co2'].mean(), 1, 0)
df_nations.sample(7)
# Out:
#                country    region           gdp  school      adfert  chldmort  \
# 42             Somalia    Africa           NaN     NaN   70.099998    180.00
# 15   Equatorial Guinea    Africa  27645.800781    5.40  122.900002    149.50
# 87         Afghanistan      Asia    938.400024    2.95  118.699997    203.00
# 144     Czech Republic    Europe  22044.599609   12.70   11.100000      4.00
# 72            Honduras  Americas   3472.399902    6.20   93.099998     31.75
# 173           Slovenia    Europe  25321.199219   10.85    5.000000      3.50
# 89          Azerbaijan      Asia   6945.000000    8.60   33.799999     38.75
#
#           life       pop      urban  femlab   literacy        co2       gini  \
# 42   50.366669   8835650  36.299999  0.6706        NaN   0.100000        NaN
# 15   50.066666    653533  39.266666  0.4140  93.300003  32.550003        NaN
# 87   47.400002  29501834  21.916666  0.3858        NaN   0.100000        NaN
# ...

# %%
df_nations['co2_record'].value_counts()
# Podemos observar que tenemos 130 casos donde las emiciones de co2 son menores que el promedio y 64 casos donde son mayores que el promedio
# Out:
# co2_record
# 0    130
# 1     64
# Name: count, dtype: int64

# %%
# para saber solo los casos donde el promedio es superior a la media puedo usar slice
df_nations['co2_record'].value_counts()[1]
# Out:
# 64

# %%
# Con el signo % entre los parentesis puedo ver el porcentaje de value_counts(%)
df_nations['co2_record'].value_counts('%')
# Out:
# co2_record
# 0    0.670103
# 1    0.329897
# Name: proportion, dtype: float64

# %%
# Respuesta pregunta 4 ¿que se puede decir del alfavetismo en africa o europa?
# Realizaremos un fuiltro para responder esta pregunta
df_nations[df_nations['region'] == 'Africa']
# Out:
#                 country  region           gdp    school      adfert  chldmort  \
# 0               Algeria  Africa   7300.399902  6.716667    7.300000     34.75
# 1                 Benin  Africa   1338.800049  3.100000  111.699997    122.75
# 2              Botswana  Africa  12307.400391  8.600000   52.099998     60.25
# 3          Burkina Faso  Africa   1063.400024  1.300000  124.800003    170.50
# 4               Burundi  Africa    349.200012  2.483333   18.600000    168.50
# 5              Cameroon  Africa   1986.800049  5.650000  127.800003    155.00
# 6            Cape Verde  Africa   3052.199951  3.500000   81.599998     30.00
# 7   Central African Rep  Africa    677.000000  3.383333  106.599998    173.50
# 8                  Chad  Africa   1266.199951  1.500000  164.500000    209.00
# 9               Comoros  Africa   1099.000000  2.800000   58.000000    105.75
# 10                Congo  Africa   3628.000000  5.850000  118.699997    125.75
# ...

# %%
df_africa = df_nations[df_nations['region'] == 'Africa']
df_africa.sample(7)
# Out:
#             country  region           gdp    school      adfert  chldmort  \
# 23            Kenya  Africa   1405.400024  6.750000  100.199997     87.75
# 22    Guinea-Bissau  Africa    967.599976  2.300000  111.099998    197.50
# 40       Seychelles  Africa  18625.800781  9.400000   51.299999     12.75
# 20            Ghana  Africa   1303.000000  6.783333   71.099998     75.25
# 21           Guinea  Africa    957.599976  1.600000  157.399994    149.50
# 11  Congo (Dem Rep)  Africa    279.799988  3.416667  201.399994    199.00
# 45        Swaziland  Africa   4468.799805  6.850000   83.900002     85.75
#
#          life       pop      urban  femlab   literacy        co2       gini  \
# 23  54.816666  38011832  21.450001  0.8626  87.000000   1.150000  47.700001
# 22  46.866669   1440083  29.766666  0.7114  52.200001   0.600000        NaN
# 40  72.983330     85167  54.066666     NaN  91.800003  30.799999  19.000000
# ...

# %%
df_europa = df_nations[df_nations['region'] == 'Europe']
df_europa.sample(7)
# Out:
#                 country  region           gdp     school     adfert  chldmort  \
# 146             Estonia  Europe  17932.000000  11.950000  22.700001      6.25
# 178      United Kingdom  Europe  33295.800781   9.066667  29.600000      6.00
# 154               Italy  Europe  28042.400391   9.816667   6.700000      4.00
# 147             Finland  Europe  32096.400391  10.183333   9.300000      3.50
# 153             Ireland  Europe  38986.800781  11.500000  17.500000      4.50
# 141  Bosnia/Herzegovina  Europe   6932.799805   8.700000  16.400000     15.00
# 149             Germany  Europe  32639.599609  12.200000   7.900000      4.50
#
#           life       pop      urban  femlab   literacy        co2       gini  \
# 146  73.733330   1342933  69.433334  0.8028  99.800003  48.849998        NaN
# 178  79.550003  61099184  79.316666  0.7916        NaN  34.099998        NaN
# 154  81.333336  59656584  67.966667  0.6246  98.900002  29.500000        NaN
# ...

# %%
df_africa['literacy'].mean()
# Out:
# 65.30851067887976

# %%
df_europa['literacy'].mean()
# Out:
# 98.17727279663086

# %% [markdown]
# ### Podemos concluir que africa tiene una taza mas baja de alfabetizacion que europa

# %% [markdown]
# # Visualizacion de datos

# %%
# Histograma con seaborn
sns.set_style("whitegrid")
sns.displot(df_nations['gini'], kind = 'hist')

# %%
# Histogramas con seaborn y matplotlib
sns.displot(df_nations['gini'], kind = 'hist',palette="colorblind")
plt.axvline(x = df_nations['gini'].mean(), color = 'r', linestyle = '--')
# Out:
# C:\Users\dmard\AppData\Local\Temp\ipykernel_7128\2921760674.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df_nations['gini'], kind = 'hist',palette="colorblind")

# %% [markdown]
# ### Realizaremos algunas comparaciones usando las funcionalidades de las librerias

# %%
'''Concentraremos datos en las siguientes variables para hacer una compraracion
entre la mortalidad infantil de europa y africa'''
media_europa = df_europa['chldmort'].mean()
media_africa = df_africa['chldmort'].mean()

# %%
sns.barplot(y=[media_africa,media_europa],x=['africa','europa'],palette="colorblind")
# Out:
# C:\Users\dmard\AppData\Local\Temp\ipykernel_7128\1050718652.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=[media_africa,media_europa],x=['africa','europa'],palette="colorblind")
# <Axes: >

# %% [markdown]
# ### Podemos apreciar que en promedio, la taza de mortalidad infantil en Africa es mucho mayor que la de Europa

# %%
# Tasa de alfavetizacion para las Americas
media_america = df_nations[df_nations['region'] == 'Americas']['literacy'].mean()
media_america
# Out:
# 89.30124988555909

# %%
media_resto_mundo = df_nations[df_nations['region'] != 'Americas']['literacy'].mean()
media_resto_mundo
# Out:
# 80.18217380357825

# %%
sns.barplot(y=[media_america,media_resto_mundo],x=['Americas','Resto del mundo'],palette="colorblind")
# Out:
# C:\Users\dmard\AppData\Local\Temp\ipykernel_7128\2442150867.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=[media_america,media_resto_mundo],x=['Americas','Resto del mundo'],palette="colorblind")
# <Axes: >

# %% [markdown]
# ### Podemos apreciar que en promedio, la taza de alfabetizacion es mas alta en las Americas que en el resto del mundo

# %%
sns.boxenplot(x = df_nations['region'], y = df_nations['school'],palette="colorblind")
# Out:
# C:\Users\dmard\AppData\Local\Temp\ipykernel_7128\1229993987.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x = df_nations['region'], y = df_nations['school'],palette="colorblind")
# <Axes: xlabel='region', ylabel='school'>

# %%
df_limpia = df_nations.dropna()
df_limpia.sample(7)
# Out:
#                 country    region           gdp    school      adfert  \
# 32              Morocco    Africa   3802.800049  4.150000   15.100000
# 169  Russian Federation    Europe  13424.799805  9.783334   30.000000
# 75            Nicaragua  Americas   2421.199951  5.450000  112.699997
# 166              Poland    Europe  15446.400391  9.816667   14.800000
# 58               Brazil  Americas   9081.200195  6.883333   75.599998
# 121               Qatar      Asia  74906.000000  7.150000   16.200001
# 113            Mongolia      Asia   2990.399902  8.266666   20.799999
#
#      chldmort       life        pop      urban  femlab   literacy         co2  \
# 32      40.75  71.150002   31168868  56.700001  0.3290  55.599998    5.550000
# 169     14.25  67.399994  143305536  73.016663  0.8206  99.599998   39.349998
# 75      28.50  72.949997    5602584  56.583336  0.5680  78.000000    2.850000
# 166      7.25  75.550003   38211584  61.183334  0.7490  99.500000   29.850000
# ...

# %%
sns.scatterplot(x=df_limpia['school'],y=df_limpia['literacy'],palette="colorblind")
# Out:
# C:\Users\dmard\AppData\Local\Temp\ipykernel_7128\532962117.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df_limpia['school'],y=df_limpia['literacy'],palette="colorblind")
# <Axes: xlabel='school', ylabel='literacy'>

# %%
sns.scatterplot(x=df_limpia['school'],y=df_limpia['gdp'],palette="colorblind")
# Out:
# C:\Users\dmard\AppData\Local\Temp\ipykernel_7128\2639235840.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df_limpia['school'],y=df_limpia['gdp'],palette="colorblind")
# <Axes: xlabel='school', ylabel='gdp'>

# %% [markdown]
# ### Heatmap de correlaciones

# %%
df_corr = df_nations
df_corr.sample(7)
# Out:
#                 country   region           gdp     school     adfert  \
# 159           Macedonia   Europe   8312.599609   8.200000  22.000000
# 123           Singapore     Asia  47373.800781   8.483334   4.800000
# 30           Mauritania   Africa   1794.199951   3.533333  79.199997
# 47                 Togo   Africa    775.000000   5.050000  65.300003
# 186         New Zealand  Oceania  25199.599609  12.366667  30.900000
# 141  Bosnia/Herzegovina   Europe   6932.799805   8.700000  16.400000
# 13             Djibouti   Africa   1972.199951   3.800000  22.900000
#
#      chldmort       life      pop       urban  femlab   literacy        co2  \
# 159     12.00  74.233337  2049833   59.149998  0.6468  97.099998  19.950001
# 123      3.00  80.550003  4677517  100.000000  0.7026  94.699997  48.750000
# 30     118.00  57.700001  3253767   40.866669  0.7168  57.500000   2.000000
# 47     102.50  55.866669  5716200   41.650002  0.7318  56.900002   0.750000
# ...

# %%
df_corr['country'] = labelencoder.fit_transform(df_nations['country'])
df_corr['region'] = labelencoder.fit_transform(df_nations['region'])
df_corr.sample(7)
# Out:
#      country  region          gdp     school     adfert  chldmort       life  \
# 38       148       0  1544.400024   4.200000  66.099998     79.25  63.833332
# 119      132       2          NaN   8.000000  53.500000     30.00  72.199997
# 68        66       1  7938.799805   8.600000  42.400002     15.25  75.366669
# 181       57       4  4259.600098  10.300000  45.200001     18.00  68.783333
# 192      180       4          NaN        NaN  23.299999     36.50  66.033333
# 193      188       4  3809.800049   6.700000  54.000000     17.75  69.966667
# 66        50       1  7170.000000   7.433333  82.800003     25.75  75.099998
#
#           pop      urban  femlab   literacy       co2  gini  gdp_peso2024  \
# 38     158800  60.166668  0.5782  88.800003  2.450000   NaN  1.496524e+06
# 119   3786333  73.599998  0.2212  94.033333  2.750000   NaN           NaN
# 68     103567  38.316666     NaN        NaN  8.299999   NaN  7.692697e+06
# ...

# %%
corr = df_corr.corr()
corr.sample(7)
# Out:
#                country    region       gdp    school    adfert  chldmort  \
# femlab       -0.091464  0.022258  0.009827  0.094663  0.032290  0.137984
# region        0.077616  1.000000  0.395040  0.610467 -0.584241 -0.577348
# chldmort     -0.077098 -0.577348 -0.516019 -0.772668  0.777416  1.000000
# gdp_peso2024  0.025964  0.395040  1.000000  0.573280 -0.517120 -0.516019
# pop          -0.048763  0.009405 -0.053251 -0.058784 -0.004868 -0.005432
# co2           0.060202  0.299778  0.826819  0.416818 -0.437615 -0.416292
# literacy      0.122941  0.545866  0.442487  0.854910 -0.676430 -0.790070
#
#                   life       pop     urban    femlab  literacy       co2  \
# femlab       -0.174210 -0.057245 -0.165942  1.000000 -0.075675 -0.101363
# region        0.591600  0.009405  0.302564  0.022258  0.545866  0.299778
# chldmort     -0.923563 -0.005432 -0.556266  0.137984 -0.790070 -0.416292
# gdp_peso2024  0.611219 -0.053251  0.656482  0.009827  0.442487  0.826819
# ...

# %%
plt.rcParams['figure.figsize'] = (10, 10)
sns.heatmap(corr,cmap = 'Greens', annot  =True)
# Out:
# <Axes: >

# %% [markdown]
# # Modelacion
#
# ### Modelo de regresion lineal

# %%
# Utilizarenmos este dataset ya que no contiene valores nulos ni perdidos y se establece que ñps datos son suficientes para realizar calculos
df_limpia.sample(7)
# Out:
#         country  region           gdp     school      adfert  chldmort  \
# 142    Bulgaria  Europe  10998.200195  10.300000   42.799999     11.50
# 105      Jordan    Asia   4782.200195   8.316667   26.500000     26.00
# 35        Niger  Africa    620.799988   1.350000  207.100006    171.75
# 27   Madagascar  Africa    919.799988   5.200000  134.300003     64.50
# 161     Moldova  Europe   2553.600098   9.533333   33.799999     18.00
# 33   Mozambique  Africa    738.599976   1.150000  149.199997    150.75
# 151     Hungary  Europe  17476.199219  10.883333   16.500000      7.00
#
#           life       pop      urban  femlab   literacy        co2       gini  \
# 142  72.783333   7616200  70.816666  0.7984  98.300003  22.599998  45.299999
# 105  72.933334   5761050  78.400002  0.3058  91.099998  13.700001  37.700001
# 35   53.033333  14222333  16.850000  0.4378  28.700001   0.250000  34.000000
# 27   65.483337  19279600  29.316666  0.9466  64.500000   0.550000  47.200001
# ...

# %%
modelo1 = smf.ols("gdp ~ co2", data = df_limpia).fit()

# %%
modelo1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    gdp   R-squared:                       0.872
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     470.4
# Date:                Sat, 02 Mar 2024   Prob (F-statistic):           1.59e-32
# Time:                        17:30:10   Log-Likelihood:                -677.72
# No. Observations:                  71   AIC:                             1359.
# Df Residuals:                      69   BIC:                             1364.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2791.2666    448.368      6.225      0.000    1896.797    3685.737
# ...
